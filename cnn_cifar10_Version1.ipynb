# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.regularizers import l2

from tensorflow.keras.optimizers import SGD

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu',
      kernel_initializer='he_uniform', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu',
      kernel_initializer='he_uniform'))
model.add(ks.layers.MaxPooling2D((2, 2)))

model.add(Dropout(0.5))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(32, activation='relu'))
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)        896
#
#  conv2d_7 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d_3 (MaxPoolin  (None, 15, 15, 32)        0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 15, 15, 32)        0
#
#  flatten_3 (Flatten)         (None, 7200)              0
#
#  dense_6 (Dense)             (None, 32)                230432
#
#  dense_7 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 240906 (941.04 KB)
# Trainable params: 240906 (941.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
               loss='sparse_categorical_crossentropy',  #son mas categorias.
               metrics=['accuracy'])

# %%
# new_sgd = SGD(learning_rate = 0.05, momentum=0.9)   # el momentum te ayuda a ir un poco mas rapido. Cuando el learning rate es muy alto, saltas y acabas empeorando el error. Para que no tarde mucho un learning rate pequeño, le ponemos momentum. Cuando ve que va bien encaminado el error, sube el learning rate, y va mas rapido.
# # momentum y learning rate. el momentum entre 0.9 y 0.99
# model.compile(optimizer=new_sgd,
#               loss='sparse_categorical_crossentropy',
#               metrics=['accuracy'], )

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane',
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
callback_loss = EarlyStopping(monitor='val_loss', patience = 15)
callback_accuracy = EarlyStopping(monitor='val_accuracy', patience = 15)

# %%
callback_check = ModelCheckpoint (filepath = 'tpm/model_check', monitor = 'val_accuracy', verbose =1, save_best_only= True, save_weights_only = True)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train, epochs=100,
                 batch_size= 50, validation_data=(x_val_scaled, y_val),
                 callbacks = [callback_check, callback_accuracy, callback_loss])
# Out:
# Epoch 1/100
# 795/800 [============================>.] - ETA: 0s - loss: 2.0740 - accuracy: 0.2295
# Epoch 1: val_accuracy improved from -inf to 0.37980, saving model to tpm/model_check
# 800/800 [==============================] - 11s 7ms/step - loss: 2.0715 - accuracy: 0.2304 - val_loss: 1.6520 - val_accuracy: 0.3798
# Epoch 2/100
# 790/800 [============================>.] - ETA: 0s - loss: 1.4884 - accuracy: 0.4386
# Epoch 2: val_accuracy improved from 0.37980 to 0.51020, saving model to tpm/model_check
# 800/800 [==============================] - 4s 5ms/step - loss: 1.4871 - accuracy: 0.4392 - val_loss: 1.3429 - val_accuracy: 0.5102
# Epoch 3/100
# 791/800 [============================>.] - ETA: 0s - loss: 1.2991 - accuracy: 0.5172
# Epoch 3: val_accuracy improved from 0.51020 to 0.56200, saving model to tpm/model_check
# 800/800 [==============================] - 4s 5ms/step - loss: 1.2987 - accuracy: 0.5175 - val_loss: 1.2022 - val_accuracy: 0.5620
# Epoch 4/100
# 797/800 [============================>.] - ETA: 0s - loss: 1.1745 - accuracy: 0.5712
# Epoch 4: val_accuracy improved from 0.56200 to 0.61150, saving model to tpm/model_check
# 800/800 [==============================] - 5s 6ms/step - loss: 1.1743 - accuracy: 0.5712 - val_loss: 1.1101 - val_accuracy: 0.6115
# Epoch 5/100
# 792/800 [============================>.] - ETA: 0s - loss: 1.0820 - accuracy: 0.6094
# Epoch 5: val_accuracy improved from 0.61150 to 0.62480, saving model to tpm/model_check
# 800/800 [==============================] - 4s 5ms/step - loss: 1.0829 - accuracy: 0.6094 - val_loss: 1.0650 - val_accuracy: 0.6248
# Epoch 6/100
# 797/800 [============================>.] - ETA: 0s - loss: 1.0408 - accuracy: 0.6262
# Epoch 6: val_accuracy improved from 0.62480 to 0.63930, saving model to tpm/model_check
# 800/800 [==============================] - 4s 5ms/step - loss: 1.0412 - accuracy: 0.6261 - val_loss: 1.0397 - val_accuracy: 0.6393
# Epoch 7/100
# 793/800 [============================>.] - ETA: 0s - loss: 1.0056 - accuracy: 0.6418
# Epoch 7: val_accuracy improved from 0.63930 to 0.65240, saving model to tpm/model_check
# 800/800 [==============================] - 5s 7ms/step - loss: 1.0055 - accuracy: 0.6417 - val_loss: 0.9958 - val_accuracy: 0.6524
# Epoch 8/100
# 791/800 [============================>.] - ETA: 0s - loss: 0.9661 - accuracy: 0.6560
# Epoch 8: val_accuracy improved from 0.65240 to 0.65950, saving model to tpm/model_check
# 800/800 [==============================] - 4s 5ms/step - loss: 0.9666 - accuracy: 0.6557 - val_loss: 0.9950 - val_accuracy: 0.6595
# Epoch 9/100
# 790/800 [============================>.] - ETA: 0s - loss: 0.9207 - accuracy: 0.6732
# Epoch 9: val_accuracy improved from 0.65950 to 0.66530, saving model to tpm/model_check
# 800/800 [==============================] - 4s 5ms/step - loss: 0.9210 - accuracy: 0.6730 - val_loss: 0.9803 - val_accuracy: 0.6653
# Epoch 10/100
# 798/800 [============================>.] - ETA: 0s - loss: 0.8880 - accuracy: 0.6863
# Epoch 10: val_accuracy improved from 0.66530 to 0.66780, saving model to tpm/model_check
# 800/800 [==============================] - 4s 5ms/step - loss: 0.8880 - accuracy: 0.6862 - val_loss: 0.9570 - val_accuracy: 0.6678
# Epoch 11/100
# 793/800 [============================>.] - ETA: 0s - loss: 0.8535 - accuracy: 0.6997
# Epoch 11: val_accuracy improved from 0.66780 to 0.68780, saving model to tpm/model_check
# 800/800 [==============================] - 4s 5ms/step - loss: 0.8533 - accuracy: 0.6996 - val_loss: 0.9149 - val_accuracy: 0.6878
# Epoch 12/100
# 789/800 [============================>.] - ETA: 0s - loss: 0.8232 - accuracy: 0.7112
# Epoch 12: val_accuracy did not improve from 0.68780
# 800/800 [==============================] - 4s 5ms/step - loss: 0.8239 - accuracy: 0.7110 - val_loss: 0.9291 - val_accuracy: 0.6780
# Epoch 13/100
# 796/800 [============================>.] - ETA: 0s - loss: 0.7979 - accuracy: 0.7173
# Epoch 13: val_accuracy improved from 0.68780 to 0.69030, saving model to tpm/model_check
# 800/800 [==============================] - 4s 5ms/step - loss: 0.7979 - accuracy: 0.7172 - val_loss: 0.9092 - val_accuracy: 0.6903
# Epoch 14/100
# 797/800 [============================>.] - ETA: 0s - loss: 0.7777 - accuracy: 0.7247
# Epoch 14: val_accuracy did not improve from 0.69030
# 800/800 [==============================] - 4s 5ms/step - loss: 0.7778 - accuracy: 0.7247 - val_loss: 0.9066 - val_accuracy: 0.6892
# Epoch 15/100
# 795/800 [============================>.] - ETA: 0s - loss: 0.7575 - accuracy: 0.7324
# Epoch 15: val_accuracy did not improve from 0.69030
# 800/800 [==============================] - 4s 5ms/step - loss: 0.7572 - accuracy: 0.7326 - val_loss: 0.9121 - val_accuracy: 0.6893
# Epoch 16/100
# 788/800 [============================>.] - ETA: 0s - loss: 0.7371 - accuracy: 0.7390
# Epoch 16: val_accuracy improved from 0.69030 to 0.69400, saving model to tpm/model_check
# 800/800 [==============================] - 4s 5ms/step - loss: 0.7372 - accuracy: 0.7389 - val_loss: 0.8896 - val_accuracy: 0.6940
# Epoch 17/100
# 793/800 [============================>.] - ETA: 0s - loss: 0.7234 - accuracy: 0.7456
# Epoch 17: val_accuracy improved from 0.69400 to 0.69580, saving model to tpm/model_check
# 800/800 [==============================] - 4s 6ms/step - loss: 0.7237 - accuracy: 0.7455 - val_loss: 0.8968 - val_accuracy: 0.6958
# Epoch 18/100
# 797/800 [============================>.] - ETA: 0s - loss: 0.7126 - accuracy: 0.7476
# Epoch 18: val_accuracy improved from 0.69580 to 0.70120, saving model to tpm/model_check
# 800/800 [==============================] - 4s 5ms/step - loss: 0.7128 - accuracy: 0.7475 - val_loss: 0.8737 - val_accuracy: 0.7012
# Epoch 19/100
# 789/800 [============================>.] - ETA: 0s - loss: 0.6973 - accuracy: 0.7546
# Epoch 19: val_accuracy did not improve from 0.70120
# 800/800 [==============================] - 4s 5ms/step - loss: 0.6973 - accuracy: 0.7546 - val_loss: 0.8986 - val_accuracy: 0.6907
# Epoch 20/100
# 789/800 [============================>.] - ETA: 0s - loss: 0.6909 - accuracy: 0.7559
# Epoch 20: val_accuracy did not improve from 0.70120
# 800/800 [==============================] - 4s 5ms/step - loss: 0.6914 - accuracy: 0.7559 - val_loss: 0.9019 - val_accuracy: 0.6913
# Epoch 21/100
# 797/800 [============================>.] - ETA: 0s - loss: 0.6719 - accuracy: 0.7609
# Epoch 21: val_accuracy did not improve from 0.70120
# 800/800 [==============================] - 4s 5ms/step - loss: 0.6722 - accuracy: 0.7609 - val_loss: 0.8787 - val_accuracy: 0.7003
# Epoch 22/100
# 791/800 [============================>.] - ETA: 0s - loss: 0.6614 - accuracy: 0.7632
# Epoch 22: val_accuracy improved from 0.70120 to 0.70140, saving model to tpm/model_check
# 800/800 [==============================] - 4s 5ms/step - loss: 0.6616 - accuracy: 0.7631 - val_loss: 0.8945 - val_accuracy: 0.7014
# Epoch 23/100
# 797/800 [============================>.] - ETA: 0s - loss: 0.6486 - accuracy: 0.7718
# Epoch 23: val_accuracy did not improve from 0.70140
# 800/800 [==============================] - 4s 5ms/step - loss: 0.6485 - accuracy: 0.7719 - val_loss: 0.9111 - val_accuracy: 0.6981
# Epoch 24/100
# 800/800 [==============================] - ETA: 0s - loss: 0.6374 - accuracy: 0.7746
# Epoch 24: val_accuracy improved from 0.70140 to 0.70500, saving model to tpm/model_check
# 800/800 [==============================] - 4s 5ms/step - loss: 0.6374 - accuracy: 0.7746 - val_loss: 0.9016 - val_accuracy: 0.7050
# Epoch 25/100
# 791/800 [============================>.] - ETA: 0s - loss: 0.6294 - accuracy: 0.7770
# Epoch 25: val_accuracy did not improve from 0.70500
# 800/800 [==============================] - 4s 5ms/step - loss: 0.6301 - accuracy: 0.7768 - val_loss: 0.9020 - val_accuracy: 0.7000
# Epoch 26/100
# 799/800 [============================>.] - ETA: 0s - loss: 0.6254 - accuracy: 0.7786
# Epoch 26: val_accuracy did not improve from 0.70500
# 800/800 [==============================] - 4s 5ms/step - loss: 0.6254 - accuracy: 0.7785 - val_loss: 0.8952 - val_accuracy: 0.7038
# Epoch 27/100
# 796/800 [============================>.] - ETA: 0s - loss: 0.6178 - accuracy: 0.7823
# Epoch 27: val_accuracy did not improve from 0.70500
# 800/800 [==============================] - 4s 5ms/step - loss: 0.6178 - accuracy: 0.7822 - val_loss: 0.9124 - val_accuracy: 0.7011
# Epoch 28/100
# 800/800 [==============================] - ETA: 0s - loss: 0.6019 - accuracy: 0.7852
# Epoch 28: val_accuracy did not improve from 0.70500
# 800/800 [==============================] - 4s 5ms/step - loss: 0.6019 - accuracy: 0.7852 - val_loss: 0.9057 - val_accuracy: 0.6999
# Epoch 29/100
# 790/800 [============================>.] - ETA: 0s - loss: 0.5970 - accuracy: 0.7886
# Epoch 29: val_accuracy did not improve from 0.70500
# 800/800 [==============================] - 4s 5ms/step - loss: 0.5962 - accuracy: 0.7886 - val_loss: 0.9121 - val_accuracy: 0.6974
# Epoch 30/100
# 794/800 [============================>.] - ETA: 0s - loss: 0.5894 - accuracy: 0.7918
# Epoch 30: val_accuracy did not improve from 0.70500
# 800/800 [==============================] - 5s 6ms/step - loss: 0.5896 - accuracy: 0.7916 - val_loss: 0.9070 - val_accuracy: 0.7027
# Epoch 31/100
# 797/800 [============================>.] - ETA: 0s - loss: 0.5867 - accuracy: 0.7915
# Epoch 31: val_accuracy improved from 0.70500 to 0.70820, saving model to tpm/model_check
# 800/800 [==============================] - 4s 5ms/step - loss: 0.5869 - accuracy: 0.7915 - val_loss: 0.8881 - val_accuracy: 0.7082
# Epoch 32/100
# 800/800 [==============================] - ETA: 0s - loss: 0.5789 - accuracy: 0.7957
# Epoch 32: val_accuracy did not improve from 0.70820
# 800/800 [==============================] - 4s 5ms/step - loss: 0.5789 - accuracy: 0.7957 - val_loss: 0.9120 - val_accuracy: 0.7022
# Epoch 33/100
# 798/800 [============================>.] - ETA: 0s - loss: 0.5630 - accuracy: 0.8001
# Epoch 33: val_accuracy did not improve from 0.70820
# 800/800 [==============================] - 5s 6ms/step - loss: 0.5631 - accuracy: 0.8001 - val_loss: 0.9041 - val_accuracy: 0.7072

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:02:25.366877

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 70.290

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_base_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
