# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime
from tensorflow.keras.optimizers import Adam

from keras.layers import Conv2D, GlobalAveragePooling2D, Dense

from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.regularizers import l2

from tensorflow.keras.optimizers import SGD

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(filters=16, kernel_size=(3,3), strides=1,
         activation='relu', kernel_initializer='he_uniform',
         kernel_regularizer = l2(0.001), padding='same', input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(filters=32, kernel_size=(3,3), strides=1,
         activation='relu', kernel_initializer='he_uniform',
         kernel_regularizer = l2(0.001), padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(filters=64, kernel_size=(3,3), strides=1,
         activation='relu', kernel_initializer='he_uniform',
         kernel_regularizer = l2(0.001), padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.GlobalAveragePooling2D())
model.add(Dropout(0.5))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(128, activation='relu',
         kernel_regularizer = l2(0.001), kernel_initializer='he_uniform'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.3))
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 16)        448
#
#  batch_normalization (Batch  (None, 32, 32, 16)        64
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        4640
#
#  batch_normalization_1 (Bat  (None, 32, 32, 32)        128
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        18496
#
#  batch_normalization_2 (Bat  (None, 32, 32, 64)        256
#  chNormalization)
#
#  global_average_pooling2d (  (None, 64)                0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 64)                0
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 128)               8320
#
#  batch_normalization_3 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 34154 (133.41 KB)
# Trainable params: 33674 (131.54 KB)
# Non-trainable params: 480 (1.88 KB)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
new_sgd = SGD(learning_rate = 0.005, momentum=0.9)
model.compile(optimizer=new_sgd,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'], )

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
callback_loss = EarlyStopping(monitor='val_loss', patience = 15)
callback_accuracy = EarlyStopping(monitor='val_accuracy', patience = 15)

# %%
callback_check = ModelCheckpoint (filepath = 'tpm/model_check', monitor = 'val_accuracy', verbose =1, save_best_only= True, save_weights_only = True)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train, epochs=100,
                 batch_size= 50, validation_data=(x_val_scaled, y_val),
                 callbacks = [callback_check, callback_accuracy, callback_loss])
# Out:
# Epoch 1/100
# 793/800 [============================>.] - ETA: 0s - loss: 2.3860 - accuracy: 0.2916
# Epoch 1: val_accuracy improved from -inf to 0.32700, saving model to tpm/model_check
# 800/800 [==============================] - 13s 8ms/step - loss: 2.3843 - accuracy: 0.2919 - val_loss: 2.1715 - val_accuracy: 0.3270
# Epoch 2/100
# 793/800 [============================>.] - ETA: 0s - loss: 2.0546 - accuracy: 0.3705
# Epoch 2: val_accuracy improved from 0.32700 to 0.37360, saving model to tpm/model_check
# 800/800 [==============================] - 6s 8ms/step - loss: 2.0541 - accuracy: 0.3709 - val_loss: 2.0072 - val_accuracy: 0.3736
# Epoch 3/100
# 796/800 [============================>.] - ETA: 0s - loss: 1.8930 - accuracy: 0.4200
# Epoch 3: val_accuracy improved from 0.37360 to 0.43660, saving model to tpm/model_check
# 800/800 [==============================] - 7s 9ms/step - loss: 1.8925 - accuracy: 0.4202 - val_loss: 1.8433 - val_accuracy: 0.4366
# Epoch 4/100
# 797/800 [============================>.] - ETA: 0s - loss: 1.7713 - accuracy: 0.4585
# Epoch 4: val_accuracy improved from 0.43660 to 0.46080, saving model to tpm/model_check
# 800/800 [==============================] - 7s 9ms/step - loss: 1.7708 - accuracy: 0.4586 - val_loss: 1.7017 - val_accuracy: 0.4608
# Epoch 5/100
# 796/800 [============================>.] - ETA: 0s - loss: 1.6712 - accuracy: 0.4856
# Epoch 5: val_accuracy improved from 0.46080 to 0.48560, saving model to tpm/model_check
# 800/800 [==============================] - 6s 7ms/step - loss: 1.6706 - accuracy: 0.4859 - val_loss: 1.7151 - val_accuracy: 0.4856
# Epoch 6/100
# 797/800 [============================>.] - ETA: 0s - loss: 1.5913 - accuracy: 0.5099
# Epoch 6: val_accuracy improved from 0.48560 to 0.50490, saving model to tpm/model_check
# 800/800 [==============================] - 6s 8ms/step - loss: 1.5911 - accuracy: 0.5101 - val_loss: 1.6107 - val_accuracy: 0.5049
# Epoch 7/100
# 797/800 [============================>.] - ETA: 0s - loss: 1.5183 - accuracy: 0.5271
# Epoch 7: val_accuracy improved from 0.50490 to 0.54230, saving model to tpm/model_check
# 800/800 [==============================] - 6s 7ms/step - loss: 1.5181 - accuracy: 0.5271 - val_loss: 1.4951 - val_accuracy: 0.5423
# Epoch 8/100
# 800/800 [==============================] - ETA: 0s - loss: 1.4673 - accuracy: 0.5429
# Epoch 8: val_accuracy improved from 0.54230 to 0.55590, saving model to tpm/model_check
# 800/800 [==============================] - 6s 8ms/step - loss: 1.4673 - accuracy: 0.5429 - val_loss: 1.4124 - val_accuracy: 0.5559
# Epoch 9/100
# 796/800 [============================>.] - ETA: 0s - loss: 1.4213 - accuracy: 0.5555
# Epoch 9: val_accuracy did not improve from 0.55590
# 800/800 [==============================] - 5s 7ms/step - loss: 1.4207 - accuracy: 0.5559 - val_loss: 1.5109 - val_accuracy: 0.5311
# Epoch 10/100
# 797/800 [============================>.] - ETA: 0s - loss: 1.3814 - accuracy: 0.5645
# Epoch 10: val_accuracy did not improve from 0.55590
# 800/800 [==============================] - 6s 8ms/step - loss: 1.3807 - accuracy: 0.5648 - val_loss: 1.7091 - val_accuracy: 0.4120
# Epoch 11/100
# 798/800 [============================>.] - ETA: 0s - loss: 1.3509 - accuracy: 0.5714
# Epoch 11: val_accuracy did not improve from 0.55590
# 800/800 [==============================] - 6s 7ms/step - loss: 1.3509 - accuracy: 0.5716 - val_loss: 1.3720 - val_accuracy: 0.5554
# Epoch 12/100
# 796/800 [============================>.] - ETA: 0s - loss: 1.3337 - accuracy: 0.5774
# Epoch 12: val_accuracy did not improve from 0.55590
# 800/800 [==============================] - 6s 8ms/step - loss: 1.3334 - accuracy: 0.5774 - val_loss: 1.5297 - val_accuracy: 0.5011
# Epoch 13/100
# 800/800 [==============================] - ETA: 0s - loss: 1.3057 - accuracy: 0.5848
# Epoch 13: val_accuracy improved from 0.55590 to 0.63360, saving model to tpm/model_check
# 800/800 [==============================] - 6s 7ms/step - loss: 1.3057 - accuracy: 0.5848 - val_loss: 1.1846 - val_accuracy: 0.6336
# Epoch 14/100
# 795/800 [============================>.] - ETA: 0s - loss: 1.2857 - accuracy: 0.5901
# Epoch 14: val_accuracy did not improve from 0.63360
# 800/800 [==============================] - 6s 7ms/step - loss: 1.2847 - accuracy: 0.5906 - val_loss: 1.3326 - val_accuracy: 0.5550
# Epoch 15/100
# 794/800 [============================>.] - ETA: 0s - loss: 1.2733 - accuracy: 0.5943
# Epoch 15: val_accuracy did not improve from 0.63360
# 800/800 [==============================] - 6s 8ms/step - loss: 1.2737 - accuracy: 0.5943 - val_loss: 1.2009 - val_accuracy: 0.6123
# Epoch 16/100
# 793/800 [============================>.] - ETA: 0s - loss: 1.2600 - accuracy: 0.5965
# Epoch 16: val_accuracy did not improve from 0.63360
# 800/800 [==============================] - 6s 7ms/step - loss: 1.2599 - accuracy: 0.5964 - val_loss: 1.2376 - val_accuracy: 0.6032
# Epoch 17/100
# 798/800 [============================>.] - ETA: 0s - loss: 1.2526 - accuracy: 0.5978
# Epoch 17: val_accuracy did not improve from 0.63360
# 800/800 [==============================] - 6s 8ms/step - loss: 1.2529 - accuracy: 0.5978 - val_loss: 1.2767 - val_accuracy: 0.5900
# Epoch 18/100
# 796/800 [============================>.] - ETA: 0s - loss: 1.2425 - accuracy: 0.6015
# Epoch 18: val_accuracy did not improve from 0.63360
# 800/800 [==============================] - 5s 7ms/step - loss: 1.2428 - accuracy: 0.6014 - val_loss: 1.2678 - val_accuracy: 0.6008
# Epoch 19/100
# 793/800 [============================>.] - ETA: 0s - loss: 1.2304 - accuracy: 0.6071
# Epoch 19: val_accuracy did not improve from 0.63360
# 800/800 [==============================] - 6s 8ms/step - loss: 1.2306 - accuracy: 0.6072 - val_loss: 1.3675 - val_accuracy: 0.5597
# Epoch 20/100
# 798/800 [============================>.] - ETA: 0s - loss: 1.2282 - accuracy: 0.6089
# Epoch 20: val_accuracy did not improve from 0.63360
# 800/800 [==============================] - 6s 7ms/step - loss: 1.2286 - accuracy: 0.6087 - val_loss: 1.1662 - val_accuracy: 0.6246
# Epoch 21/100
# 800/800 [==============================] - ETA: 0s - loss: 1.2141 - accuracy: 0.6120
# Epoch 21: val_accuracy did not improve from 0.63360
# 800/800 [==============================] - 6s 8ms/step - loss: 1.2141 - accuracy: 0.6120 - val_loss: 1.3058 - val_accuracy: 0.5854
# Epoch 22/100
# 796/800 [============================>.] - ETA: 0s - loss: 1.2114 - accuracy: 0.6125
# Epoch 22: val_accuracy did not improve from 0.63360
# 800/800 [==============================] - 5s 7ms/step - loss: 1.2105 - accuracy: 0.6129 - val_loss: 1.2691 - val_accuracy: 0.5870
# Epoch 23/100
# 797/800 [============================>.] - ETA: 0s - loss: 1.2033 - accuracy: 0.6167
# Epoch 23: val_accuracy did not improve from 0.63360
# 800/800 [==============================] - 6s 7ms/step - loss: 1.2036 - accuracy: 0.6166 - val_loss: 1.3417 - val_accuracy: 0.5686
# Epoch 24/100
# 795/800 [============================>.] - ETA: 0s - loss: 1.2076 - accuracy: 0.6184
# Epoch 24: val_accuracy did not improve from 0.63360
# 800/800 [==============================] - 6s 7ms/step - loss: 1.2084 - accuracy: 0.6181 - val_loss: 1.2746 - val_accuracy: 0.5938
# Epoch 25/100
# 794/800 [============================>.] - ETA: 0s - loss: 1.1995 - accuracy: 0.6203
# Epoch 25: val_accuracy did not improve from 0.63360
# 800/800 [==============================] - 6s 7ms/step - loss: 1.1996 - accuracy: 0.6205 - val_loss: 1.2571 - val_accuracy: 0.5914
# Epoch 26/100
# 798/800 [============================>.] - ETA: 0s - loss: 1.1926 - accuracy: 0.6208
# Epoch 26: val_accuracy did not improve from 0.63360
# 800/800 [==============================] - 6s 8ms/step - loss: 1.1928 - accuracy: 0.6208 - val_loss: 1.2403 - val_accuracy: 0.5934
# Epoch 27/100
# 794/800 [============================>.] - ETA: 0s - loss: 1.1874 - accuracy: 0.6251
# Epoch 27: val_accuracy did not improve from 0.63360
# 800/800 [==============================] - 6s 8ms/step - loss: 1.1870 - accuracy: 0.6250 - val_loss: 1.2428 - val_accuracy: 0.6015
# Epoch 28/100
# 799/800 [============================>.] - ETA: 0s - loss: 1.1817 - accuracy: 0.6275
# Epoch 28: val_accuracy did not improve from 0.63360
# 800/800 [==============================] - 6s 8ms/step - loss: 1.1816 - accuracy: 0.6275 - val_loss: 1.3447 - val_accuracy: 0.5730

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:02:57.805350

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 56.470

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_base_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
