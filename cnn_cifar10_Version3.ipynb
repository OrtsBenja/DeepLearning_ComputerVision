# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.regularizers import l2

from tensorflow.keras.optimizers import SGD

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(filters=16, kernel_size=(3,3), strides=1,
         activation='relu', kernel_initializer='he_uniform',
         kernel_regularizer = l2(0.001), padding='same', input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(filters=16, kernel_size=(3,3), strides=1,
         activation='relu', kernel_initializer='he_uniform',
         kernel_regularizer = l2(0.001), padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(Dropout(0.5))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(64, activation='relu',
         kernel_regularizer = l2(0.001), kernel_initializer='he_uniform'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.3))
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 32, 32, 16)        448
#
#  batch_normalization_6 (Bat  (None, 32, 32, 16)        64
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 16)        2320
#
#  batch_normalization_7 (Bat  (None, 32, 32, 16)        64
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 16)        0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 16, 16, 16)        0
#
#  flatten_2 (Flatten)         (None, 4096)              0
#
#  dense_4 (Dense)             (None, 64)                262208
#
#  batch_normalization_8 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 266010 (1.01 MB)
# Trainable params: 265818 (1.01 MB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
new_sgd = SGD(learning_rate = 0.005, momentum=0.9)   # el momentum te ayuda a ir un poco mas rapido. Cuando el learning rate es muy alto, saltas y acabas empeorando el error. Para que no tarde mucho un learning rate pequeño, le ponemos momentum. Cuando ve que va bien encaminado el error, sube el learning rate, y va mas rapido.
# momentum y learning rate. el momentum entre 0.9 y 0.99
model.compile(optimizer=new_sgd,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'], )

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
callback_loss = EarlyStopping(monitor='val_loss', patience = 15)
callback_accuracy = EarlyStopping(monitor='val_accuracy', patience = 15)

# %%
callback_check = ModelCheckpoint (filepath = 'tpm/model_check', monitor = 'val_accuracy', verbose =1, save_best_only= True, save_weights_only = True)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train, epochs=100,
                 batch_size= 50, validation_data=(x_val_scaled, y_val),
                 callbacks = [callback_check, callback_accuracy, callback_loss])
# Out:
# Epoch 1/100
# 796/800 [============================>.] - ETA: 0s - loss: 1.8336 - accuracy: 0.4161
# Epoch 1: val_accuracy improved from -inf to 0.51250, saving model to tpm/model_check
# 800/800 [==============================] - 7s 7ms/step - loss: 1.8326 - accuracy: 0.4164 - val_loss: 1.5432 - val_accuracy: 0.5125
# Epoch 2/100
# 793/800 [============================>.] - ETA: 0s - loss: 1.5292 - accuracy: 0.5180
# Epoch 2: val_accuracy improved from 0.51250 to 0.55830, saving model to tpm/model_check
# 800/800 [==============================] - 4s 5ms/step - loss: 1.5288 - accuracy: 0.5180 - val_loss: 1.4380 - val_accuracy: 0.5583
# Epoch 3/100
# 795/800 [============================>.] - ETA: 0s - loss: 1.4016 - accuracy: 0.5629
# Epoch 3: val_accuracy improved from 0.55830 to 0.60810, saving model to tpm/model_check
# 800/800 [==============================] - 5s 6ms/step - loss: 1.4012 - accuracy: 0.5633 - val_loss: 1.2871 - val_accuracy: 0.6081
# Epoch 4/100
# 792/800 [============================>.] - ETA: 0s - loss: 1.3214 - accuracy: 0.5905
# Epoch 4: val_accuracy did not improve from 0.60810
# 800/800 [==============================] - 5s 6ms/step - loss: 1.3206 - accuracy: 0.5907 - val_loss: 1.2953 - val_accuracy: 0.5895
# Epoch 5/100
# 798/800 [============================>.] - ETA: 0s - loss: 1.2567 - accuracy: 0.6146
# Epoch 5: val_accuracy improved from 0.60810 to 0.63780, saving model to tpm/model_check
# 800/800 [==============================] - 4s 5ms/step - loss: 1.2565 - accuracy: 0.6145 - val_loss: 1.1937 - val_accuracy: 0.6378
# Epoch 6/100
# 799/800 [============================>.] - ETA: 0s - loss: 1.2210 - accuracy: 0.6278
# Epoch 6: val_accuracy improved from 0.63780 to 0.64840, saving model to tpm/model_check
# 800/800 [==============================] - 5s 6ms/step - loss: 1.2213 - accuracy: 0.6277 - val_loss: 1.1580 - val_accuracy: 0.6484
# Epoch 7/100
# 792/800 [============================>.] - ETA: 0s - loss: 1.1904 - accuracy: 0.6336
# Epoch 7: val_accuracy improved from 0.64840 to 0.66170, saving model to tpm/model_check
# 800/800 [==============================] - 5s 6ms/step - loss: 1.1902 - accuracy: 0.6338 - val_loss: 1.1234 - val_accuracy: 0.6617
# Epoch 8/100
# 794/800 [============================>.] - ETA: 0s - loss: 1.1616 - accuracy: 0.6442
# Epoch 8: val_accuracy improved from 0.66170 to 0.66900, saving model to tpm/model_check
# 800/800 [==============================] - 4s 5ms/step - loss: 1.1619 - accuracy: 0.6441 - val_loss: 1.1078 - val_accuracy: 0.6690
# Epoch 9/100
# 796/800 [============================>.] - ETA: 0s - loss: 1.1474 - accuracy: 0.6509
# Epoch 9: val_accuracy did not improve from 0.66900
# 800/800 [==============================] - 5s 6ms/step - loss: 1.1469 - accuracy: 0.6510 - val_loss: 1.1574 - val_accuracy: 0.6529
# Epoch 10/100
# 797/800 [============================>.] - ETA: 0s - loss: 1.1267 - accuracy: 0.6591
# Epoch 10: val_accuracy improved from 0.66900 to 0.67410, saving model to tpm/model_check
# 800/800 [==============================] - 4s 5ms/step - loss: 1.1269 - accuracy: 0.6591 - val_loss: 1.0878 - val_accuracy: 0.6741
# Epoch 11/100
# 800/800 [==============================] - ETA: 0s - loss: 1.1166 - accuracy: 0.6618
# Epoch 11: val_accuracy did not improve from 0.67410
# 800/800 [==============================] - 4s 5ms/step - loss: 1.1166 - accuracy: 0.6618 - val_loss: 1.1003 - val_accuracy: 0.6728
# Epoch 12/100
# 796/800 [============================>.] - ETA: 0s - loss: 1.1086 - accuracy: 0.6659
# Epoch 12: val_accuracy did not improve from 0.67410
# 800/800 [==============================] - 5s 7ms/step - loss: 1.1085 - accuracy: 0.6660 - val_loss: 1.3365 - val_accuracy: 0.5916
# Epoch 13/100
# 795/800 [============================>.] - ETA: 0s - loss: 1.0999 - accuracy: 0.6710
# Epoch 13: val_accuracy improved from 0.67410 to 0.67430, saving model to tpm/model_check
# 800/800 [==============================] - 4s 5ms/step - loss: 1.0997 - accuracy: 0.6711 - val_loss: 1.1085 - val_accuracy: 0.6743
# Epoch 14/100
# 791/800 [============================>.] - ETA: 0s - loss: 1.0924 - accuracy: 0.6745
# Epoch 14: val_accuracy did not improve from 0.67430
# 800/800 [==============================] - 4s 5ms/step - loss: 1.0915 - accuracy: 0.6750 - val_loss: 1.1796 - val_accuracy: 0.6428
# Epoch 15/100
# 792/800 [============================>.] - ETA: 0s - loss: 1.0782 - accuracy: 0.6793
# Epoch 15: val_accuracy did not improve from 0.67430
# 800/800 [==============================] - 5s 6ms/step - loss: 1.0784 - accuracy: 0.6792 - val_loss: 1.1113 - val_accuracy: 0.6652
# Epoch 16/100
# 793/800 [============================>.] - ETA: 0s - loss: 1.0756 - accuracy: 0.6799
# Epoch 16: val_accuracy did not improve from 0.67430
# 800/800 [==============================] - 4s 5ms/step - loss: 1.0766 - accuracy: 0.6793 - val_loss: 1.2300 - val_accuracy: 0.6342
# Epoch 17/100
# 790/800 [============================>.] - ETA: 0s - loss: 1.0767 - accuracy: 0.6816
# Epoch 17: val_accuracy improved from 0.67430 to 0.68370, saving model to tpm/model_check
# 800/800 [==============================] - 4s 5ms/step - loss: 1.0772 - accuracy: 0.6815 - val_loss: 1.0822 - val_accuracy: 0.6837
# Epoch 18/100
# 799/800 [============================>.] - ETA: 0s - loss: 1.0698 - accuracy: 0.6861
# Epoch 18: val_accuracy did not improve from 0.68370
# 800/800 [==============================] - 5s 6ms/step - loss: 1.0698 - accuracy: 0.6861 - val_loss: 1.1459 - val_accuracy: 0.6594
# Epoch 19/100
# 791/800 [============================>.] - ETA: 0s - loss: 1.0641 - accuracy: 0.6872
# Epoch 19: val_accuracy did not improve from 0.68370
# 800/800 [==============================] - 4s 5ms/step - loss: 1.0641 - accuracy: 0.6873 - val_loss: 1.2135 - val_accuracy: 0.6380
# Epoch 20/100
# 799/800 [============================>.] - ETA: 0s - loss: 1.0652 - accuracy: 0.6874
# Epoch 20: val_accuracy did not improve from 0.68370
# 800/800 [==============================] - 4s 6ms/step - loss: 1.0650 - accuracy: 0.6874 - val_loss: 1.1784 - val_accuracy: 0.6511
# Epoch 21/100
# 790/800 [============================>.] - ETA: 0s - loss: 1.0611 - accuracy: 0.6927
# Epoch 21: val_accuracy improved from 0.68370 to 0.68890, saving model to tpm/model_check
# 800/800 [==============================] - 5s 6ms/step - loss: 1.0616 - accuracy: 0.6924 - val_loss: 1.0667 - val_accuracy: 0.6889
# Epoch 22/100
# 795/800 [============================>.] - ETA: 0s - loss: 1.0658 - accuracy: 0.6910
# Epoch 22: val_accuracy did not improve from 0.68890
# 800/800 [==============================] - 4s 5ms/step - loss: 1.0654 - accuracy: 0.6912 - val_loss: 1.1280 - val_accuracy: 0.6716
# Epoch 23/100
# 797/800 [============================>.] - ETA: 0s - loss: 1.0601 - accuracy: 0.6929
# Epoch 23: val_accuracy did not improve from 0.68890
# 800/800 [==============================] - 5s 6ms/step - loss: 1.0597 - accuracy: 0.6931 - val_loss: 1.1623 - val_accuracy: 0.6561
# Epoch 24/100
# 798/800 [============================>.] - ETA: 0s - loss: 1.0668 - accuracy: 0.6905
# Epoch 24: val_accuracy did not improve from 0.68890
# 800/800 [==============================] - 6s 7ms/step - loss: 1.0669 - accuracy: 0.6905 - val_loss: 1.1015 - val_accuracy: 0.6795
# Epoch 25/100
# 797/800 [============================>.] - ETA: 0s - loss: 1.0557 - accuracy: 0.6960
# Epoch 25: val_accuracy did not improve from 0.68890
# 800/800 [==============================] - 5s 6ms/step - loss: 1.0561 - accuracy: 0.6959 - val_loss: 1.3032 - val_accuracy: 0.6339
# Epoch 26/100
# 793/800 [============================>.] - ETA: 0s - loss: 1.0505 - accuracy: 0.6979
# Epoch 26: val_accuracy improved from 0.68890 to 0.69160, saving model to tpm/model_check
# 800/800 [==============================] - 5s 6ms/step - loss: 1.0512 - accuracy: 0.6980 - val_loss: 1.0828 - val_accuracy: 0.6916
# Epoch 27/100
# 798/800 [============================>.] - ETA: 0s - loss: 1.0581 - accuracy: 0.6950
# Epoch 27: val_accuracy did not improve from 0.69160
# 800/800 [==============================] - 4s 5ms/step - loss: 1.0583 - accuracy: 0.6950 - val_loss: 1.1862 - val_accuracy: 0.6548
# Epoch 28/100
# 792/800 [============================>.] - ETA: 0s - loss: 1.0502 - accuracy: 0.6975
# Epoch 28: val_accuracy did not improve from 0.69160
# 800/800 [==============================] - 4s 5ms/step - loss: 1.0515 - accuracy: 0.6971 - val_loss: 1.2026 - val_accuracy: 0.6538
# Epoch 29/100
# 796/800 [============================>.] - ETA: 0s - loss: 1.0533 - accuracy: 0.7005
# Epoch 29: val_accuracy did not improve from 0.69160
# 800/800 [==============================] - 5s 6ms/step - loss: 1.0534 - accuracy: 0.7004 - val_loss: 1.1457 - val_accuracy: 0.6680
# Epoch 30/100
# 800/800 [==============================] - ETA: 0s - loss: 1.0449 - accuracy: 0.7014
# Epoch 30: val_accuracy did not improve from 0.69160
# 800/800 [==============================] - 4s 6ms/step - loss: 1.0449 - accuracy: 0.7014 - val_loss: 1.1236 - val_accuracy: 0.6783
# Epoch 31/100
# 797/800 [============================>.] - ETA: 0s - loss: 1.0535 - accuracy: 0.6995
# Epoch 31: val_accuracy improved from 0.69160 to 0.69840, saving model to tpm/model_check
# 800/800 [==============================] - 4s 6ms/step - loss: 1.0532 - accuracy: 0.6998 - val_loss: 1.0637 - val_accuracy: 0.6984
# Epoch 32/100
# 793/800 [============================>.] - ETA: 0s - loss: 1.0497 - accuracy: 0.7032
# Epoch 32: val_accuracy did not improve from 0.69840
# 800/800 [==============================] - 5s 6ms/step - loss: 1.0506 - accuracy: 0.7030 - val_loss: 1.1446 - val_accuracy: 0.6764
# Epoch 33/100
# 793/800 [============================>.] - ETA: 0s - loss: 1.0505 - accuracy: 0.7039
# Epoch 33: val_accuracy did not improve from 0.69840
# 800/800 [==============================] - 4s 5ms/step - loss: 1.0514 - accuracy: 0.7034 - val_loss: 1.1379 - val_accuracy: 0.6716
# Epoch 34/100
# 793/800 [============================>.] - ETA: 0s - loss: 1.0527 - accuracy: 0.7009
# Epoch 34: val_accuracy did not improve from 0.69840
# 800/800 [==============================] - 4s 5ms/step - loss: 1.0526 - accuracy: 0.7010 - val_loss: 1.0710 - val_accuracy: 0.6949
# Epoch 35/100
# 795/800 [============================>.] - ETA: 0s - loss: 1.0487 - accuracy: 0.7030
# Epoch 35: val_accuracy improved from 0.69840 to 0.70450, saving model to tpm/model_check
# 800/800 [==============================] - 5s 6ms/step - loss: 1.0501 - accuracy: 0.7025 - val_loss: 1.0521 - val_accuracy: 0.7045
# Epoch 36/100
# 799/800 [============================>.] - ETA: 0s - loss: 1.0497 - accuracy: 0.7024
# Epoch 36: val_accuracy did not improve from 0.70450
# 800/800 [==============================] - 4s 5ms/step - loss: 1.0495 - accuracy: 0.7025 - val_loss: 1.1338 - val_accuracy: 0.6798
# Epoch 37/100
# 795/800 [============================>.] - ETA: 0s - loss: 1.0411 - accuracy: 0.7062
# Epoch 37: val_accuracy did not improve from 0.70450
# 800/800 [==============================] - 4s 6ms/step - loss: 1.0409 - accuracy: 0.7063 - val_loss: 1.0787 - val_accuracy: 0.6906
# Epoch 38/100
# 794/800 [============================>.] - ETA: 0s - loss: 1.0466 - accuracy: 0.7050
# Epoch 38: val_accuracy did not improve from 0.70450
# 800/800 [==============================] - 5s 6ms/step - loss: 1.0468 - accuracy: 0.7049 - val_loss: 1.1194 - val_accuracy: 0.6814
# Epoch 39/100
# 795/800 [============================>.] - ETA: 0s - loss: 1.0467 - accuracy: 0.7065
# Epoch 39: val_accuracy did not improve from 0.70450
# 800/800 [==============================] - 4s 6ms/step - loss: 1.0469 - accuracy: 0.7062 - val_loss: 1.1545 - val_accuracy: 0.6709
# Epoch 40/100
# 791/800 [============================>.] - ETA: 0s - loss: 1.0426 - accuracy: 0.7087
# Epoch 40: val_accuracy did not improve from 0.70450
# 800/800 [==============================] - 4s 5ms/step - loss: 1.0431 - accuracy: 0.7086 - val_loss: 1.1262 - val_accuracy: 0.6797
# Epoch 41/100
# 797/800 [============================>.] - ETA: 0s - loss: 1.0421 - accuracy: 0.7059
# Epoch 41: val_accuracy did not improve from 0.70450
# 800/800 [==============================] - 5s 6ms/step - loss: 1.0420 - accuracy: 0.7059 - val_loss: 1.0712 - val_accuracy: 0.6964
# Epoch 42/100
# 791/800 [============================>.] - ETA: 0s - loss: 1.0444 - accuracy: 0.7062
# Epoch 42: val_accuracy did not improve from 0.70450
# 800/800 [==============================] - 4s 6ms/step - loss: 1.0451 - accuracy: 0.7061 - val_loss: 1.1891 - val_accuracy: 0.6643
# Epoch 43/100
# 794/800 [============================>.] - ETA: 0s - loss: 1.0409 - accuracy: 0.7074
# Epoch 43: val_accuracy did not improve from 0.70450
# 800/800 [==============================] - 5s 6ms/step - loss: 1.0412 - accuracy: 0.7075 - val_loss: 1.1792 - val_accuracy: 0.6653
# Epoch 44/100
# 795/800 [============================>.] - ETA: 0s - loss: 1.0441 - accuracy: 0.7089
# Epoch 44: val_accuracy did not improve from 0.70450
# 800/800 [==============================] - 5s 6ms/step - loss: 1.0446 - accuracy: 0.7086 - val_loss: 1.0737 - val_accuracy: 0.6976
# Epoch 45/100
# 798/800 [============================>.] - ETA: 0s - loss: 1.0433 - accuracy: 0.7091
# Epoch 45: val_accuracy did not improve from 0.70450
# 800/800 [==============================] - 4s 5ms/step - loss: 1.0433 - accuracy: 0.7090 - val_loss: 1.0706 - val_accuracy: 0.7016
# Epoch 46/100
# 797/800 [============================>.] - ETA: 0s - loss: 1.0401 - accuracy: 0.7115
# Epoch 46: val_accuracy did not improve from 0.70450
# 800/800 [==============================] - 5s 6ms/step - loss: 1.0397 - accuracy: 0.7115 - val_loss: 1.1467 - val_accuracy: 0.6759
# Epoch 47/100
# 792/800 [============================>.] - ETA: 0s - loss: 1.0414 - accuracy: 0.7083
# Epoch 47: val_accuracy did not improve from 0.70450
# 800/800 [==============================] - 4s 5ms/step - loss: 1.0420 - accuracy: 0.7081 - val_loss: 1.0918 - val_accuracy: 0.6962
# Epoch 48/100
# 793/800 [============================>.] - ETA: 0s - loss: 1.0378 - accuracy: 0.7090
# Epoch 48: val_accuracy did not improve from 0.70450
# 800/800 [==============================] - 4s 5ms/step - loss: 1.0375 - accuracy: 0.7091 - val_loss: 1.1255 - val_accuracy: 0.6896
# Epoch 49/100
# 797/800 [============================>.] - ETA: 0s - loss: 1.0440 - accuracy: 0.7100
# Epoch 49: val_accuracy did not improve from 0.70450
# 800/800 [==============================] - 5s 6ms/step - loss: 1.0442 - accuracy: 0.7100 - val_loss: 1.1143 - val_accuracy: 0.6901
# Epoch 50/100
# 797/800 [============================>.] - ETA: 0s - loss: 1.0368 - accuracy: 0.7103
# Epoch 50: val_accuracy did not improve from 0.70450
# 800/800 [==============================] - 4s 5ms/step - loss: 1.0364 - accuracy: 0.7106 - val_loss: 1.1252 - val_accuracy: 0.6843

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:03:52.606267

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 67.510

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_base_model.h5')
