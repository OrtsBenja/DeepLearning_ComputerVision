# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.regularizers import l1, l2, l1_l2

from tensorflow.keras.optimizers import SGD

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(filters=16, kernel_size=(3,3), strides=1,
         activation='relu', kernel_initializer='he_uniform', padding='same',
         input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(filters=32, kernel_size=(3,3), strides=1,
         activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(filters=64, kernel_size=(3,3), strides=1,
         activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(filters=128, kernel_size=(3,3), strides=1,
         activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(Dropout(0.5))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(64, activation='relu', kernel_initializer='he_uniform'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dense(32, activation='relu', kernel_initializer='he_uniform'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.3))
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 16)        448
#
#  batch_normalization (Batch  (None, 32, 32, 16)        64
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        4640
#
#  batch_normalization_1 (Bat  (None, 32, 32, 32)        128
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        18496
#
#  batch_normalization_2 (Bat  (None, 32, 32, 64)        256
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 128)       73856
#
#  batch_normalization_3 (Bat  (None, 32, 32, 128)       512
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 128)       0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 128)       0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 64)                2097216
#
#  batch_normalization_4 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  batch_normalization_5 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 2198410 (8.39 MB)
# Trainable params: 2197738 (8.38 MB)
# Non-trainable params: 672 (2.62 KB)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
new_adam = Adam(learning_rate=0.01)

# %%
model.compile(optimizer='Adam',
               loss='sparse_categorical_crossentropy',
               metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
callback_loss = EarlyStopping(monitor='val_loss', patience = 15)
callback_accuracy = EarlyStopping(monitor='val_accuracy', patience = 15)

# %%
callback_check = ModelCheckpoint (filepath = 'tpm/model_check', monitor = 'val_accuracy', verbose =1, save_best_only= True, save_weights_only = True)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train, epochs=100,
                 batch_size= 50, validation_data=(x_val_scaled, y_val),
                 callbacks = [callback_check, callback_accuracy, callback_loss])
# Out:
# Epoch 1/100
# 793/800 [============================>.] - ETA: 0s - loss: 1.5158 - accuracy: 0.4692
# Epoch 1: val_accuracy improved from -inf to 0.60260, saving model to tpm/model_check
# 800/800 [==============================] - 16s 8ms/step - loss: 1.5129 - accuracy: 0.4705 - val_loss: 1.1001 - val_accuracy: 0.6026
# Epoch 2/100
# 799/800 [============================>.] - ETA: 0s - loss: 1.0798 - accuracy: 0.6240
# Epoch 2: val_accuracy improved from 0.60260 to 0.63860, saving model to tpm/model_check
# 800/800 [==============================] - 5s 7ms/step - loss: 1.0796 - accuracy: 0.6241 - val_loss: 1.0076 - val_accuracy: 0.6386
# Epoch 3/100
# 798/800 [============================>.] - ETA: 0s - loss: 0.9219 - accuracy: 0.6828
# Epoch 3: val_accuracy did not improve from 0.63860
# 800/800 [==============================] - 5s 6ms/step - loss: 0.9223 - accuracy: 0.6827 - val_loss: 1.1088 - val_accuracy: 0.6050
# Epoch 4/100
# 799/800 [============================>.] - ETA: 0s - loss: 0.8080 - accuracy: 0.7235
# Epoch 4: val_accuracy improved from 0.63860 to 0.70050, saving model to tpm/model_check
# 800/800 [==============================] - 5s 7ms/step - loss: 0.8078 - accuracy: 0.7236 - val_loss: 0.8684 - val_accuracy: 0.7005
# Epoch 5/100
# 798/800 [============================>.] - ETA: 0s - loss: 0.7004 - accuracy: 0.7627
# Epoch 5: val_accuracy improved from 0.70050 to 0.72800, saving model to tpm/model_check
# 800/800 [==============================] - 5s 7ms/step - loss: 0.7002 - accuracy: 0.7626 - val_loss: 0.8112 - val_accuracy: 0.7280
# Epoch 6/100
# 799/800 [============================>.] - ETA: 0s - loss: 0.6403 - accuracy: 0.7832
# Epoch 6: val_accuracy improved from 0.72800 to 0.73060, saving model to tpm/model_check
# 800/800 [==============================] - 5s 7ms/step - loss: 0.6404 - accuracy: 0.7832 - val_loss: 0.7872 - val_accuracy: 0.7306
# Epoch 7/100
# 797/800 [============================>.] - ETA: 0s - loss: 0.5358 - accuracy: 0.8177
# Epoch 7: val_accuracy improved from 0.73060 to 0.73910, saving model to tpm/model_check
# 800/800 [==============================] - 5s 7ms/step - loss: 0.5353 - accuracy: 0.8178 - val_loss: 0.7775 - val_accuracy: 0.7391
# Epoch 8/100
# 800/800 [==============================] - ETA: 0s - loss: 0.4540 - accuracy: 0.8440
# Epoch 8: val_accuracy improved from 0.73910 to 0.74250, saving model to tpm/model_check
# 800/800 [==============================] - 5s 7ms/step - loss: 0.4540 - accuracy: 0.8440 - val_loss: 0.7861 - val_accuracy: 0.7425
# Epoch 9/100
# 797/800 [============================>.] - ETA: 0s - loss: 0.3965 - accuracy: 0.8633
# Epoch 9: val_accuracy improved from 0.74250 to 0.74960, saving model to tpm/model_check
# 800/800 [==============================] - 5s 7ms/step - loss: 0.3966 - accuracy: 0.8632 - val_loss: 0.7789 - val_accuracy: 0.7496
# Epoch 10/100
# 798/800 [============================>.] - ETA: 0s - loss: 0.3426 - accuracy: 0.8828
# Epoch 10: val_accuracy did not improve from 0.74960
# 800/800 [==============================] - 5s 6ms/step - loss: 0.3431 - accuracy: 0.8826 - val_loss: 0.8500 - val_accuracy: 0.7461
# Epoch 11/100
# 797/800 [============================>.] - ETA: 0s - loss: 0.3060 - accuracy: 0.8960
# Epoch 11: val_accuracy did not improve from 0.74960
# 800/800 [==============================] - 5s 7ms/step - loss: 0.3060 - accuracy: 0.8959 - val_loss: 0.8613 - val_accuracy: 0.7476
# Epoch 12/100
# 793/800 [============================>.] - ETA: 0s - loss: 0.2852 - accuracy: 0.9032
# Epoch 12: val_accuracy improved from 0.74960 to 0.75050, saving model to tpm/model_check
# 800/800 [==============================] - 5s 7ms/step - loss: 0.2856 - accuracy: 0.9031 - val_loss: 0.8439 - val_accuracy: 0.7505
# Epoch 13/100
# 797/800 [============================>.] - ETA: 0s - loss: 0.2558 - accuracy: 0.9148
# Epoch 13: val_accuracy improved from 0.75050 to 0.75140, saving model to tpm/model_check
# 800/800 [==============================] - 5s 7ms/step - loss: 0.2560 - accuracy: 0.9147 - val_loss: 0.8836 - val_accuracy: 0.7514
# Epoch 14/100
# 799/800 [============================>.] - ETA: 0s - loss: 0.2307 - accuracy: 0.9212
# Epoch 14: val_accuracy improved from 0.75140 to 0.75190, saving model to tpm/model_check
# 800/800 [==============================] - 5s 7ms/step - loss: 0.2306 - accuracy: 0.9212 - val_loss: 0.9228 - val_accuracy: 0.7519
# Epoch 15/100
# 794/800 [============================>.] - ETA: 0s - loss: 0.2183 - accuracy: 0.9266
# Epoch 15: val_accuracy improved from 0.75190 to 0.75450, saving model to tpm/model_check
# 800/800 [==============================] - 5s 7ms/step - loss: 0.2183 - accuracy: 0.9266 - val_loss: 0.9073 - val_accuracy: 0.7545
# Epoch 16/100
# 797/800 [============================>.] - ETA: 0s - loss: 0.1914 - accuracy: 0.9350
# Epoch 16: val_accuracy did not improve from 0.75450
# 800/800 [==============================] - 5s 6ms/step - loss: 0.1916 - accuracy: 0.9348 - val_loss: 0.9839 - val_accuracy: 0.7398
# Epoch 17/100
# 797/800 [============================>.] - ETA: 0s - loss: 0.1907 - accuracy: 0.9348
# Epoch 17: val_accuracy did not improve from 0.75450
# 800/800 [==============================] - 5s 6ms/step - loss: 0.1910 - accuracy: 0.9348 - val_loss: 0.9570 - val_accuracy: 0.7473
# Epoch 18/100
# 799/800 [============================>.] - ETA: 0s - loss: 0.1699 - accuracy: 0.9420
# Epoch 18: val_accuracy did not improve from 0.75450
# 800/800 [==============================] - 5s 6ms/step - loss: 0.1703 - accuracy: 0.9419 - val_loss: 0.9759 - val_accuracy: 0.7530
# Epoch 19/100
# 797/800 [============================>.] - ETA: 0s - loss: 0.1655 - accuracy: 0.9433
# Epoch 19: val_accuracy improved from 0.75450 to 0.75520, saving model to tpm/model_check
# 800/800 [==============================] - 5s 7ms/step - loss: 0.1654 - accuracy: 0.9434 - val_loss: 0.9540 - val_accuracy: 0.7552
# Epoch 20/100
# 792/800 [============================>.] - ETA: 0s - loss: 0.1610 - accuracy: 0.9460
# Epoch 20: val_accuracy improved from 0.75520 to 0.75670, saving model to tpm/model_check
# 800/800 [==============================] - 5s 7ms/step - loss: 0.1614 - accuracy: 0.9460 - val_loss: 0.9678 - val_accuracy: 0.7567
# Epoch 21/100
# 798/800 [============================>.] - ETA: 0s - loss: 0.1502 - accuracy: 0.9495
# Epoch 21: val_accuracy did not improve from 0.75670
# 800/800 [==============================] - 5s 6ms/step - loss: 0.1504 - accuracy: 0.9494 - val_loss: 1.0108 - val_accuracy: 0.7512
# Epoch 22/100
# 794/800 [============================>.] - ETA: 0s - loss: 0.1401 - accuracy: 0.9538
# Epoch 22: val_accuracy did not improve from 0.75670
# 800/800 [==============================] - 5s 7ms/step - loss: 0.1399 - accuracy: 0.9538 - val_loss: 0.9710 - val_accuracy: 0.7550

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:02:07.743886

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 75.340

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_base_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
