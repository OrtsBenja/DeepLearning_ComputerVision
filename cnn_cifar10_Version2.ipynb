# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.regularizers import l2

from tensorflow.keras.optimizers import SGD

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(filters=16, kernel_size=(3,3), strides=1,
         activation='relu', kernel_initializer='he_uniform',padding='same',
         input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(filters=16, kernel_size=(3,3), strides=1,
         activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(Dropout(0.5))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(64, activation='relu',
         kernel_initializer='he_uniform'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.3))
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 32, 32, 16)        448
#
#  batch_normalization_6 (Bat  (None, 32, 32, 16)        64
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 16)        2320
#
#  batch_normalization_7 (Bat  (None, 32, 32, 16)        64
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 16)        0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 16, 16, 16)        0
#
#  flatten_2 (Flatten)         (None, 4096)              0
#
#  dense_4 (Dense)             (None, 64)                262208
#
#  batch_normalization_8 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 266010 (1.01 MB)
# Trainable params: 265818 (1.01 MB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
new_adam = Adam(learning_rate=0.01)

# %%
model.compile(optimizer='Adam',
               loss='sparse_categorical_crossentropy',
               metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane',
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
callback_loss = EarlyStopping(monitor='val_loss', patience = 15)
callback_accuracy = EarlyStopping(monitor='val_accuracy', patience = 15)

# %%
callback_check = ModelCheckpoint (filepath = 'tpm/model_check', monitor = 'val_accuracy', verbose =1, save_best_only= True, save_weights_only = True)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train, epochs=100,
                 batch_size= 50, validation_data=(x_val_scaled, y_val),
                 callbacks = [callback_check, callback_accuracy, callback_loss])
# Out:
# Epoch 1/100
# 798/800 [============================>.] - ETA: 0s - loss: 1.6292 - accuracy: 0.4309
# Epoch 1: val_accuracy improved from -inf to 0.53570, saving model to tpm/model_check
# 800/800 [==============================] - 8s 7ms/step - loss: 1.6286 - accuracy: 0.4311 - val_loss: 1.3982 - val_accuracy: 0.5357
# Epoch 2/100
# 794/800 [============================>.] - ETA: 0s - loss: 1.2697 - accuracy: 0.5501
# Epoch 2: val_accuracy improved from 0.53570 to 0.61070, saving model to tpm/model_check
# 800/800 [==============================] - 7s 9ms/step - loss: 1.2694 - accuracy: 0.5502 - val_loss: 1.1031 - val_accuracy: 0.6107
# Epoch 3/100
# 795/800 [============================>.] - ETA: 0s - loss: 1.1436 - accuracy: 0.5945
# Epoch 3: val_accuracy improved from 0.61070 to 0.62720, saving model to tpm/model_check
# 800/800 [==============================] - 5s 6ms/step - loss: 1.1431 - accuracy: 0.5949 - val_loss: 1.0469 - val_accuracy: 0.6272
# Epoch 4/100
# 797/800 [============================>.] - ETA: 0s - loss: 1.0771 - accuracy: 0.6186
# Epoch 4: val_accuracy improved from 0.62720 to 0.64940, saving model to tpm/model_check
# 800/800 [==============================] - 5s 7ms/step - loss: 1.0776 - accuracy: 0.6185 - val_loss: 0.9978 - val_accuracy: 0.6494
# Epoch 5/100
# 800/800 [==============================] - ETA: 0s - loss: 1.0298 - accuracy: 0.6384
# Epoch 5: val_accuracy improved from 0.64940 to 0.66440, saving model to tpm/model_check
# 800/800 [==============================] - 5s 6ms/step - loss: 1.0298 - accuracy: 0.6384 - val_loss: 0.9618 - val_accuracy: 0.6644
# Epoch 6/100
# 793/800 [============================>.] - ETA: 0s - loss: 0.9903 - accuracy: 0.6523
# Epoch 6: val_accuracy improved from 0.66440 to 0.66470, saving model to tpm/model_check
# 800/800 [==============================] - 5s 6ms/step - loss: 0.9900 - accuracy: 0.6526 - val_loss: 0.9651 - val_accuracy: 0.6647
# Epoch 7/100
# 794/800 [============================>.] - ETA: 0s - loss: 0.9690 - accuracy: 0.6593
# Epoch 7: val_accuracy improved from 0.66470 to 0.66980, saving model to tpm/model_check
# 800/800 [==============================] - 6s 7ms/step - loss: 0.9687 - accuracy: 0.6592 - val_loss: 0.9333 - val_accuracy: 0.6698
# Epoch 8/100
# 795/800 [============================>.] - ETA: 0s - loss: 0.9412 - accuracy: 0.6684
# Epoch 8: val_accuracy improved from 0.66980 to 0.67470, saving model to tpm/model_check
# 800/800 [==============================] - 5s 6ms/step - loss: 0.9413 - accuracy: 0.6683 - val_loss: 0.9329 - val_accuracy: 0.6747
# Epoch 9/100
# 795/800 [============================>.] - ETA: 0s - loss: 0.9150 - accuracy: 0.6764
# Epoch 9: val_accuracy improved from 0.67470 to 0.68130, saving model to tpm/model_check
# 800/800 [==============================] - 5s 6ms/step - loss: 0.9149 - accuracy: 0.6762 - val_loss: 0.9079 - val_accuracy: 0.6813
# Epoch 10/100
# 797/800 [============================>.] - ETA: 0s - loss: 0.9058 - accuracy: 0.6808
# Epoch 10: val_accuracy improved from 0.68130 to 0.68610, saving model to tpm/model_check
# 800/800 [==============================] - 5s 6ms/step - loss: 0.9064 - accuracy: 0.6806 - val_loss: 0.8948 - val_accuracy: 0.6861
# Epoch 11/100
# 790/800 [============================>.] - ETA: 0s - loss: 0.8843 - accuracy: 0.6879
# Epoch 11: val_accuracy did not improve from 0.68610
# 800/800 [==============================] - 5s 6ms/step - loss: 0.8841 - accuracy: 0.6880 - val_loss: 0.9073 - val_accuracy: 0.6786
# Epoch 12/100
# 797/800 [============================>.] - ETA: 0s - loss: 0.8699 - accuracy: 0.6930
# Epoch 12: val_accuracy did not improve from 0.68610
# 800/800 [==============================] - 5s 7ms/step - loss: 0.8696 - accuracy: 0.6931 - val_loss: 0.9088 - val_accuracy: 0.6834
# Epoch 13/100
# 791/800 [============================>.] - ETA: 0s - loss: 0.8492 - accuracy: 0.6988
# Epoch 13: val_accuracy did not improve from 0.68610
# 800/800 [==============================] - 5s 7ms/step - loss: 0.8501 - accuracy: 0.6983 - val_loss: 0.9495 - val_accuracy: 0.6712
# Epoch 14/100
# 796/800 [============================>.] - ETA: 0s - loss: 0.8332 - accuracy: 0.7067
# Epoch 14: val_accuracy improved from 0.68610 to 0.68780, saving model to tpm/model_check
# 800/800 [==============================] - 4s 6ms/step - loss: 0.8334 - accuracy: 0.7067 - val_loss: 0.8863 - val_accuracy: 0.6878
# Epoch 15/100
# 799/800 [============================>.] - ETA: 0s - loss: 0.8274 - accuracy: 0.7097
# Epoch 15: val_accuracy improved from 0.68780 to 0.68940, saving model to tpm/model_check
# 800/800 [==============================] - 5s 7ms/step - loss: 0.8278 - accuracy: 0.7096 - val_loss: 0.8779 - val_accuracy: 0.6894
# Epoch 16/100
# 794/800 [============================>.] - ETA: 0s - loss: 0.8190 - accuracy: 0.7099
# Epoch 16: val_accuracy improved from 0.68940 to 0.69590, saving model to tpm/model_check
# 800/800 [==============================] - 5s 6ms/step - loss: 0.8188 - accuracy: 0.7100 - val_loss: 0.8568 - val_accuracy: 0.6959
# Epoch 17/100
# 795/800 [============================>.] - ETA: 0s - loss: 0.8070 - accuracy: 0.7123
# Epoch 17: val_accuracy did not improve from 0.69590
# 800/800 [==============================] - 5s 6ms/step - loss: 0.8061 - accuracy: 0.7125 - val_loss: 0.9110 - val_accuracy: 0.6803
# Epoch 18/100
# 800/800 [==============================] - ETA: 0s - loss: 0.7989 - accuracy: 0.7161
# Epoch 18: val_accuracy improved from 0.69590 to 0.69710, saving model to tpm/model_check
# 800/800 [==============================] - 5s 7ms/step - loss: 0.7989 - accuracy: 0.7161 - val_loss: 0.8760 - val_accuracy: 0.6971
# Epoch 19/100
# 791/800 [============================>.] - ETA: 0s - loss: 0.7957 - accuracy: 0.7187
# Epoch 19: val_accuracy did not improve from 0.69710
# 800/800 [==============================] - 5s 6ms/step - loss: 0.7965 - accuracy: 0.7183 - val_loss: 0.8594 - val_accuracy: 0.6963
# Epoch 20/100
# 799/800 [============================>.] - ETA: 0s - loss: 0.7738 - accuracy: 0.7220
# Epoch 20: val_accuracy improved from 0.69710 to 0.71030, saving model to tpm/model_check
# 800/800 [==============================] - 5s 7ms/step - loss: 0.7738 - accuracy: 0.7219 - val_loss: 0.8272 - val_accuracy: 0.7103
# Epoch 21/100
# 793/800 [============================>.] - ETA: 0s - loss: 0.7758 - accuracy: 0.7224
# Epoch 21: val_accuracy did not improve from 0.71030
# 800/800 [==============================] - 5s 6ms/step - loss: 0.7765 - accuracy: 0.7225 - val_loss: 0.8402 - val_accuracy: 0.7049
# Epoch 22/100
# 794/800 [============================>.] - ETA: 0s - loss: 0.7656 - accuracy: 0.7297
# Epoch 22: val_accuracy did not improve from 0.71030
# 800/800 [==============================] - 4s 5ms/step - loss: 0.7657 - accuracy: 0.7298 - val_loss: 0.9309 - val_accuracy: 0.6786
# Epoch 23/100
# 799/800 [============================>.] - ETA: 0s - loss: 0.7579 - accuracy: 0.7315
# Epoch 23: val_accuracy did not improve from 0.71030
# 800/800 [==============================] - 5s 6ms/step - loss: 0.7580 - accuracy: 0.7314 - val_loss: 0.8310 - val_accuracy: 0.7078
# Epoch 24/100
# 797/800 [============================>.] - ETA: 0s - loss: 0.7549 - accuracy: 0.7314
# Epoch 24: val_accuracy did not improve from 0.71030
# 800/800 [==============================] - 5s 6ms/step - loss: 0.7553 - accuracy: 0.7312 - val_loss: 0.8804 - val_accuracy: 0.6943
# Epoch 25/100
# 797/800 [============================>.] - ETA: 0s - loss: 0.7465 - accuracy: 0.7339
# Epoch 25: val_accuracy did not improve from 0.71030
# 800/800 [==============================] - 5s 6ms/step - loss: 0.7458 - accuracy: 0.7342 - val_loss: 0.8420 - val_accuracy: 0.7024
# Epoch 26/100
# 800/800 [==============================] - ETA: 0s - loss: 0.7341 - accuracy: 0.7410
# Epoch 26: val_accuracy did not improve from 0.71030
# 800/800 [==============================] - 5s 7ms/step - loss: 0.7341 - accuracy: 0.7410 - val_loss: 0.8743 - val_accuracy: 0.6991
# Epoch 27/100
# 795/800 [============================>.] - ETA: 0s - loss: 0.7355 - accuracy: 0.7362
# Epoch 27: val_accuracy did not improve from 0.71030
# 800/800 [==============================] - 5s 6ms/step - loss: 0.7356 - accuracy: 0.7362 - val_loss: 0.9089 - val_accuracy: 0.6873
# Epoch 28/100
# 795/800 [============================>.] - ETA: 0s - loss: 0.7337 - accuracy: 0.7385
# Epoch 28: val_accuracy improved from 0.71030 to 0.71540, saving model to tpm/model_check
# 800/800 [==============================] - 6s 8ms/step - loss: 0.7338 - accuracy: 0.7385 - val_loss: 0.8222 - val_accuracy: 0.7154
# Epoch 29/100
# 795/800 [============================>.] - ETA: 0s - loss: 0.7283 - accuracy: 0.7396
# Epoch 29: val_accuracy did not improve from 0.71540
# 800/800 [==============================] - 5s 6ms/step - loss: 0.7284 - accuracy: 0.7395 - val_loss: 0.8429 - val_accuracy: 0.7055
# Epoch 30/100
# 791/800 [============================>.] - ETA: 0s - loss: 0.7204 - accuracy: 0.7423
# Epoch 30: val_accuracy did not improve from 0.71540
# 800/800 [==============================] - 5s 6ms/step - loss: 0.7218 - accuracy: 0.7418 - val_loss: 0.8583 - val_accuracy: 0.7026
# Epoch 31/100
# 795/800 [============================>.] - ETA: 0s - loss: 0.7189 - accuracy: 0.7440
# Epoch 31: val_accuracy did not improve from 0.71540
# 800/800 [==============================] - 6s 7ms/step - loss: 0.7190 - accuracy: 0.7441 - val_loss: 0.8490 - val_accuracy: 0.7048
# Epoch 32/100
# 792/800 [============================>.] - ETA: 0s - loss: 0.7081 - accuracy: 0.7501
# Epoch 32: val_accuracy did not improve from 0.71540
# 800/800 [==============================] - 5s 6ms/step - loss: 0.7084 - accuracy: 0.7500 - val_loss: 0.8224 - val_accuracy: 0.7143
# Epoch 33/100
# 799/800 [============================>.] - ETA: 0s - loss: 0.7123 - accuracy: 0.7459
# Epoch 33: val_accuracy did not improve from 0.71540
# 800/800 [==============================] - 5s 6ms/step - loss: 0.7124 - accuracy: 0.7459 - val_loss: 0.8522 - val_accuracy: 0.7022
# Epoch 34/100
# 797/800 [============================>.] - ETA: 0s - loss: 0.7046 - accuracy: 0.7501
# Epoch 34: val_accuracy did not improve from 0.71540
# 800/800 [==============================] - 5s 7ms/step - loss: 0.7043 - accuracy: 0.7502 - val_loss: 0.8142 - val_accuracy: 0.7154
# Epoch 35/100
# 794/800 [============================>.] - ETA: 0s - loss: 0.7000 - accuracy: 0.7498
# Epoch 35: val_accuracy did not improve from 0.71540
# 800/800 [==============================] - 5s 6ms/step - loss: 0.6997 - accuracy: 0.7499 - val_loss: 0.8356 - val_accuracy: 0.7113
# Epoch 36/100
# 796/800 [============================>.] - ETA: 0s - loss: 0.6964 - accuracy: 0.7506
# Epoch 36: val_accuracy improved from 0.71540 to 0.72030, saving model to tpm/model_check
# 800/800 [==============================] - 6s 7ms/step - loss: 0.6970 - accuracy: 0.7506 - val_loss: 0.8186 - val_accuracy: 0.7203
# Epoch 37/100
# 792/800 [============================>.] - ETA: 0s - loss: 0.6964 - accuracy: 0.7519
# Epoch 37: val_accuracy did not improve from 0.72030
# 800/800 [==============================] - 5s 6ms/step - loss: 0.6959 - accuracy: 0.7521 - val_loss: 0.8296 - val_accuracy: 0.7145
# Epoch 38/100
# 796/800 [============================>.] - ETA: 0s - loss: 0.6944 - accuracy: 0.7512
# Epoch 38: val_accuracy did not improve from 0.72030
# 800/800 [==============================] - 5s 6ms/step - loss: 0.6938 - accuracy: 0.7516 - val_loss: 0.8284 - val_accuracy: 0.7131
# Epoch 39/100
# 799/800 [============================>.] - ETA: 0s - loss: 0.6899 - accuracy: 0.7522
# Epoch 39: val_accuracy did not improve from 0.72030
# 800/800 [==============================] - 6s 7ms/step - loss: 0.6899 - accuracy: 0.7522 - val_loss: 0.8305 - val_accuracy: 0.7112
# Epoch 40/100
# 795/800 [============================>.] - ETA: 0s - loss: 0.6954 - accuracy: 0.7492
# Epoch 40: val_accuracy did not improve from 0.72030
# 800/800 [==============================] - 5s 6ms/step - loss: 0.6946 - accuracy: 0.7495 - val_loss: 0.8360 - val_accuracy: 0.7116
# Epoch 41/100
# 794/800 [============================>.] - ETA: 0s - loss: 0.6847 - accuracy: 0.7541
# Epoch 41: val_accuracy did not improve from 0.72030
# 800/800 [==============================] - 5s 7ms/step - loss: 0.6844 - accuracy: 0.7543 - val_loss: 0.8248 - val_accuracy: 0.7163
# Epoch 42/100
# 798/800 [============================>.] - ETA: 0s - loss: 0.6844 - accuracy: 0.7567
# Epoch 42: val_accuracy did not improve from 0.72030
# 800/800 [==============================] - 5s 6ms/step - loss: 0.6845 - accuracy: 0.7568 - val_loss: 0.8318 - val_accuracy: 0.7155
# Epoch 43/100
# 800/800 [==============================] - ETA: 0s - loss: 0.6721 - accuracy: 0.7581
# Epoch 43: val_accuracy did not improve from 0.72030
# 800/800 [==============================] - 5s 6ms/step - loss: 0.6721 - accuracy: 0.7581 - val_loss: 0.8146 - val_accuracy: 0.7166
# Epoch 44/100
# 791/800 [============================>.] - ETA: 0s - loss: 0.6666 - accuracy: 0.7607
# Epoch 44: val_accuracy did not improve from 0.72030
# 800/800 [==============================] - 6s 7ms/step - loss: 0.6676 - accuracy: 0.7603 - val_loss: 0.8143 - val_accuracy: 0.7177
# Epoch 45/100
# 795/800 [============================>.] - ETA: 0s - loss: 0.6690 - accuracy: 0.7609
# Epoch 45: val_accuracy did not improve from 0.72030
# 800/800 [==============================] - 5s 6ms/step - loss: 0.6696 - accuracy: 0.7607 - val_loss: 0.8529 - val_accuracy: 0.7075
# Epoch 46/100
# 797/800 [============================>.] - ETA: 0s - loss: 0.6639 - accuracy: 0.7644
# Epoch 46: val_accuracy did not improve from 0.72030
# 800/800 [==============================] - 5s 6ms/step - loss: 0.6641 - accuracy: 0.7644 - val_loss: 0.8598 - val_accuracy: 0.7023
# Epoch 47/100
# 791/800 [============================>.] - ETA: 0s - loss: 0.6649 - accuracy: 0.7615
# Epoch 47: val_accuracy did not improve from 0.72030
# 800/800 [==============================] - 5s 6ms/step - loss: 0.6652 - accuracy: 0.7615 - val_loss: 0.8180 - val_accuracy: 0.7170
# Epoch 48/100
# 792/800 [============================>.] - ETA: 0s - loss: 0.6616 - accuracy: 0.7641
# Epoch 48: val_accuracy did not improve from 0.72030
# 800/800 [==============================] - 5s 6ms/step - loss: 0.6620 - accuracy: 0.7641 - val_loss: 0.8666 - val_accuracy: 0.7035
# Epoch 49/100
# 798/800 [============================>.] - ETA: 0s - loss: 0.6627 - accuracy: 0.7622
# Epoch 49: val_accuracy did not improve from 0.72030
# 800/800 [==============================] - 5s 7ms/step - loss: 0.6628 - accuracy: 0.7620 - val_loss: 0.8354 - val_accuracy: 0.7130

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:04:12.971225

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 70.750

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_base_model.h5')
